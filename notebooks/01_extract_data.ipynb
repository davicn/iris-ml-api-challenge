# %% [markdown]
# # Extração de Dados

# %%
import pandas as pd

# %% [markdown]
# ## Download de Base

# %%
# !wget https://archive.ics.uci.edu/static/public/53/iris.zip
# !unzip iris.zip -d data/raw/
# !rm iris.zip
# Out:
# --2025-05-28 18:16:18--  https://archive.ics.uci.edu/static/public/53/iris.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘iris.zip’
#
# iris.zip                [ <=>                ]   3.65K  --.-KB/s    in 0s
#
# 2025-05-28 18:16:19 (433 MB/s) - ‘iris.zip’ saved [3738]
#
# Archive:  iris.zip
#   inflating: data/raw/Index
#   inflating: data/raw/bezdekIris.data
#   inflating: data/raw/iris.data
#   inflating: data/raw/iris.names

# %%
df = pd.read_csv(
    'data/raw/iris.data',
    names=['sepal_length','sepal_width ','petal_length','petal_width','class'])

df.head()
# Out:
#    sepal_length  sepal_width   petal_length  petal_width        class
# 0           5.1           3.5           1.4          0.2  Iris-setosa
# 1           4.9           3.0           1.4          0.2  Iris-setosa
# 2           4.7           3.2           1.3          0.2  Iris-setosa
# 3           4.6           3.1           1.5          0.2  Iris-setosa
# 4           5.0           3.6           1.4          0.2  Iris-setosa

# %%
df.to_parquet('data/trusted/iris.parquet',index=False)
